# %%
import numpy as np
import pandas as pd
import datetime
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

df=pd.read_csv('movies_dataset_processed.csv')
df
# Out:
#       Unnamed: 0  IMDb-rating appropriate_for                   director
# 0              0          4.8               R                  John Swab  \
# 1              1          6.4           TV-PG                Paul Ziller
# 2              2          5.2               R               Ben Wheatley
# 3              3          6.5               R             Benjamin Caron
# 4              4          6.9           PG-13                Ravi Kapoor
# ...          ...          ...             ...                        ...
# 9897        9897          7.1       Not Rated                  Biren Nag
# 9898        9898          7.0               G               Guy Hamilton
# 9899        9899          5.6               R  Barbara Topsøe-Rothenborg
# 9900        9900          7.1       Not Rated                  Biren Nag
# 9901        9901          7.0               G               Guy Hamilton
#
#      downloads  industry                      language posted_date
# ...

# %%
release_year=[]
for date in df['release_date']:
    date_object=datetime.datetime.strptime(date,'%Y-%m-%d')
    release_year.append(date_object.year)
df['release_year']=release_year

# %%
df.drop(['Unnamed: 0','storyline','writer','title','language'],axis=1,inplace=True)
df
# Out:
#       IMDb-rating appropriate_for                   director downloads
# 0             4.8               R                  John Swab       304  \
# 1             6.4           TV-PG                Paul Ziller        73
# 2             5.2               R               Ben Wheatley     1,427
# 3             6.5               R             Benjamin Caron     1,781
# 4             6.9           PG-13                Ravi Kapoor       458
# ...           ...             ...                        ...       ...
# 9897          7.1       Not Rated                  Biren Nag     1,932
# 9898          7.0               G               Guy Hamilton     2,544
# 9899          5.6               R  Barbara Topsøe-Rothenborg    12,284
# 9900          7.1       Not Rated                  Biren Nag     1,932
# 9901          7.0               G               Guy Hamilton     2,544
#
#       industry posted_date release_date  run_time   views  days_to_post
# ...

# %%
# languages=set([])
# for i in df['language']:
#     d_lang=i.split(',')
#     for j in d_lang:
#         languages.add(j)
# languages

# %%
cols_to_label_enc=['appropriate_for','director','industry']
label_encs=[]
for col in cols_to_label_enc:
    enc=LabelEncoder()
    enc.fit(df[col].unique())
    df[col]=enc.transform(df[col])
    label_encs.append(enc)

# %%
cols_to_float=['downloads','views']
for col in cols_to_float:
    np_list=[]
    for i in range(df.shape[0]):
        np_list.append(int(str(df[col][i]).replace(',','')))
    df[col]=np_list
df
# Out:
#       IMDb-rating  appropriate_for  director  downloads  industry posted_date
# 0             4.8               10      2363        304         4  2023-02-20  \
# 1             6.4               15      3715         73         4  2023-02-20
# 2             5.2               10       532       1427         4  2021-04-20
# 3             6.5               10       540       1781         4  2023-02-13
# 4             6.9                8      3946        458         4  2023-02-18
# ...           ...              ...       ...        ...       ...         ...
# 9897          7.1                6       594       1932         2  1970-01-01
# 9898          7.0                3      1785       2544         4  1970-01-01
# 9899          5.6               10       482      12284         4  2016-05-26
# 9900          7.1                6       594       1932         2  1970-01-01
# 9901          7.0                3      1785       2544         4  1970-01-01
#
# ...

# %% [markdown]
# ## For all features

# %%
X_cols=['IMDb-rating','appropriate_for','director','downloads','industry','run_time','views','release_year']
Y_cols=['days_to_post']
X_train, X_test, y_train, y_test = train_test_split(df[X_cols],df[Y_cols],test_size=0.3,random_state=32)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

lr=LinearRegression()
lr.fit(X_train,y_train)

lr.score(X_test,y_test)
# Out:
# 0.7495377325260799

# %% [markdown]
# ## Removing industry

# %%
X_cols=['IMDb-rating','appropriate_for','director','downloads','run_time','views','release_year']
Y_cols=['days_to_post']
X_train, X_test, y_train, y_test = train_test_split(df[X_cols],df[Y_cols],test_size=0.3,random_state=32)

# %%
lr=LinearRegression()
lr.fit(X_train,y_train)

lr.score(X_test,y_test)
# Out:
# 0.745281223014655

# %% [markdown]
# ## Removing Director

# %%
X_cols=['IMDb-rating','appropriate_for','downloads','industry','run_time','views','release_year']
Y_cols=['days_to_post']
X_train, X_test, y_train, y_test = train_test_split(df[X_cols],df[Y_cols],test_size=0.3,random_state=32)

lr=LinearRegression()
lr.fit(X_train,y_train)

lr.score(X_test,y_test)
# Out:
# 0.7493723583689409

# %% [markdown]
# ## Removing Appropriate_for

# %%
X_cols=['IMDb-rating','director','downloads','industry','run_time','views','release_year']
Y_cols=['days_to_post']
X_train, X_test, y_train, y_test = train_test_split(df[X_cols],df[Y_cols],test_size=0.3,random_state=32)

lr=LinearRegression()
lr.fit(X_train,y_train)

lr.score(X_test,y_test)
# Out:
# 0.7440097681893716

# %% [markdown]
# ## Removing Views

# %%
X_cols=['IMDb-rating','appropriate_for','director','downloads','industry','run_time','release_year']
Y_cols=['days_to_post']
X_train, X_test, y_train, y_test = train_test_split(df[X_cols],df[Y_cols],test_size=0.3,random_state=32)

lr=LinearRegression()
lr.fit(X_train,y_train)

lr.score(X_test,y_test)
# Out:
# 0.7449515645175186

# %% [markdown]
# ## Removing IMDB Rating

# %%
X_cols=['appropriate_for','director','downloads','industry','run_time','views','release_year']
Y_cols=['days_to_post']
X_train, X_test, y_train, y_test = train_test_split(df[X_cols],df[Y_cols],test_size=0.3,random_state=32)

lr=LinearRegression()
lr.fit(X_train,y_train)

lr.score(X_test,y_test)
# Out:
# 0.7489406229615099

# %% [markdown]
# ## Removing Downloads

# %%
X_cols=['IMDb-rating','appropriate_for','director','industry','run_time','views','release_year']
Y_cols=['days_to_post']
X_train, X_test, y_train, y_test = train_test_split(df[X_cols],df[Y_cols],test_size=0.3,random_state=32)

lr=LinearRegression()
lr.fit(X_train,y_train)

lr.score(X_test,y_test)
# Out:
# 0.7431589949650856

# %% [markdown]
# ## Removing Release Year

# %%
X_cols=['IMDb-rating','appropriate_for','director','downloads','industry','run_time','views']
Y_cols=['days_to_post']
X_train, X_test, y_train, y_test = train_test_split(df[X_cols],df[Y_cols],test_size=0.3,random_state=32)

lr=LinearRegression()
lr.fit(X_train,y_train)

lr.score(X_test,y_test)
# Out:
# 0.01943945723880669

# %%
X_cols=['release_year']
Y_cols=['days_to_post']
X_train, X_test, y_train, y_test = train_test_split(df[X_cols],df[Y_cols],test_size=0.3,random_state=32)

lr=LinearRegression()
lr.fit(X_train,y_train)

lr.score(X_test,y_test)
# Out:
# 0.7215963292865352

# %% [markdown]
# ### Keeping release year constant and seeing the relations bw other features

# %%
filtered_df = df[df['release_year'] == 2023]
X_cols=['IMDb-rating','appropriate_for','director','downloads','industry','run_time','views']
Y_cols=['days_to_post']
X_train, X_test, y_train, y_test = train_test_split(filtered_df[X_cols],filtered_df[Y_cols],test_size=0.3,random_state=32)


lr=LinearRegression()
lr.fit(X_train,y_train)

lr.score(X_test,y_test)
# Out:
# -61.410256854232344

# %%
from sklearn.linear_model import LogisticRegression
sk_lr=LogisticRegression()
sk_lr.fit(X_train,y_train.ravel())

logreg_train_accuracy = sk_lr.score(X_train,y_train)
logreg_test_accuracy = sk_lr.score(X_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [31], line 3
#       1 from sklearn.linear_model import LogisticRegression
#       2 sk_lr=LogisticRegression()
# ----> 3 sk_lr.fit(X_train,y_train.ravel())
#       5 logreg_train_accuracy = sk_lr.score(X_train,y_train)
#       6 logreg_test_accuracy = sk_lr.score(X_test, y_test)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/generic.py:5989, in NDFrame.__getattr__(self, name)
#    5982 if (
#    5983     name not in self._internal_names_set
#    5984     and name not in self._metadata
#    5985     and name not in self._accessors
#    5986     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987 ):
#    5988     return self[name]
# -> 5989 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'ravel'
